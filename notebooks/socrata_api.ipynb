# %%
import pandas as pd
import requests

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("9hwr-2zxp", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
start_date = "2022-01-31"
end_date = "2022-12-31"

# %%
base_url = "https://data.cityofchicago.org/resource/9hwr-2zxp.json"
params = {
            "$where": f"date between '{start_date}' and '{end_date}'",
            "$limit": 50000  # Limite définie pour éviter une surcharge de données
        }

# %%
response = requests.get(base_url, params=params)

# %%
data = response.json()

# %%
data
# Out:
# [{'date': '2022-12-31T00:00:00.000',
#   'location': {'latitude': '42.005821436',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}',
#    'needs_recoding': False,
#    'longitude': '-87.696032791'},
#   'district': '024',
#   'block': '026XX W FARWELL AVE',
#   'y_coordinate': '1945356',
#   'latitude': '42.005821436',
#   'description': 'AUTOMOBILE',
#   'location_description': 'STREET',
#   'updated_on': '2023-01-07T15:41:08.000',
#   'community_area': '2',
#   'iucr': '0910',
#   'x_coordinate': '1157461',
#   'ward': '50',
#   'case_number': 'JF528633',
#   'year': '2022',
#   'domestic': False,
#   'fbi_code': '07',
#   'longitude': '-87.696032791',
#   'beat': '2411',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'arrest': False,
#   'id': '12937754'},
#  {'date': '2022-12-31T00:00:00.000',
#   'location': {'latitude': '41.765185248',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}',
#    'needs_recoding': False,
# ...

# %%
results_df = pd.DataFrame.from_records(data)

# %%
results_df
# Out:
#                           date  \
# 0      2022-12-31T00:00:00.000
# 1      2022-12-31T00:00:00.000
# 2      2022-12-31T00:00:00.000
# 3      2022-12-31T00:00:00.000
# 4      2022-12-31T00:00:00.000
# ...                        ...
# 49995  2022-10-19T04:00:00.000
# 49996  2022-10-19T03:50:00.000
# 49997  2022-10-19T03:50:00.000
# 49998  2022-10-19T03:45:00.000
# 49999  2022-10-19T03:40:00.000
#
#                                                 location district  \
# 0      {'latitude': '42.005821436', 'human_address': ...      024
# 1      {'latitude': '41.765185248', 'human_address': ...      003
# 2      {'latitude': '41.72831222', 'human_address': '...      022
# 3      {'latitude': '41.727636065', 'human_address': ...      006
# 4      {'latitude': '41.885393253', 'human_address': ...      012
# ...                                                  ...      ...
# 49995  {'latitude': '41.990427791', 'human_address': ...      016
# ...
